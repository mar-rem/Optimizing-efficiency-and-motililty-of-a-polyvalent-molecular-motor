# %%
# %pylab inline
import seaborn as sb
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
f = open("GM12878_OE_KRnorm_1M_chr2.txt","r")

file = f.readlines()
contact = []
col1 = []
col2 = []

size = 243
matrix = zeros((size-1,size-1))

for i in file:
    contact.append(float(i.split("\t")[2][:-2]))
    col1.append(float(i.split("\t")[0]))
    col2.append(float(i.split("\t")[1]))

# find where the strange gap is
for i in range(len(col1)-1):
    diff = col1[i+1] -col1[i]
    if diff > 1000000:
        print(col1[i],col1[i+1])
        
print(len(contact))

p = 0       
for j in range(size-1):
    for k in range(j+1):
        print(j,k,p)
        matrix[j][k] = contact[p]
        matrix[k][j] = contact[p]
        p += 1
        
print(matrix)
# Out:
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# 92000000.0 95000000.0
# ...

# %%
sb.heatmap(matrix)
# Out:
# <AxesSubplot:>

# %%
print(max(contact),min(contact))
# Out:
# 12.21916 0.058095

# %%
evalues = linalg.eig(matrix)[0]
evectors = linalg.eig(matrix)[1]
plot(flip(sort(abs(evalues[:25]))),".")
title("Top 25 Eigenvalues")
ylabel("Eigenvalues")
print(evalues)
# Out:
# [ 2.37920559e+02  7.09327866e+01  3.89940457e+01  2.70046337e+01
#  -1.65914042e+01 -1.41658195e+01  1.45108209e+01  1.24146781e+01
#   1.06433231e+01 -1.11668318e+01 -9.66682760e+00  7.77245597e+00
#  -8.22177568e+00  6.23980603e+00 -7.03932723e+00  5.91531303e+00
#  -6.46332996e+00 -5.90040230e+00 -5.83881860e+00  4.92052683e+00
#  -5.16366992e+00  3.48390706e+00 -4.85261743e+00 -4.54201349e+00
#   2.91210503e+00  2.78742276e+00 -4.10177286e+00 -3.99883390e+00
#  -3.95761053e+00 -3.88929644e+00  2.62576370e+00 -3.71633027e+00
#  -3.59098165e+00  2.34667502e+00 -3.35345116e+00  2.12571572e+00
#   2.10022999e+00 -3.12900932e+00  1.92889290e+00  1.86031036e+00
#  -2.95295508e+00 -2.84066653e+00 -2.82215684e+00 -2.60632327e+00
#  -2.54737772e+00 -2.47817396e+00 -2.39201316e+00 -2.37047938e+00
#   1.70342767e+00  1.60456190e+00  1.41214953e+00  1.37086598e+00
#   1.32978431e+00 -2.31155096e+00  1.22632130e+00  1.10935109e+00
# ...

# %%
plot(evectors[0])

# %%
plot(evectors[1])

# %%
plot(evectors[2])
